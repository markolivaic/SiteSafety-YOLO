# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt
import numpy as np
import os

model_path = '../yolov8n.pt' 

model = YOLO(model_path)  

def show_inference(img_path):
    if not os.path.exists(img_path):
        print(f"Greška: Slika nije pronađena na {img_path}")
        return

    results = model(img_path)
    
    for r in results:
        im_array = r.plot()
        im_rgb = cv2.cvtColor(im_array, cv2.COLOR_BGR2RGB)
        
        plt.figure(figsize=(12, 8))
        plt.imshow(im_rgb)
        plt.axis('off')
        plt.title(f'Detection Result')
        plt.show()

show_inference('../data/input/test_image.png')
# Out:
# image 1/1 c:\Users\makif\NEXT\SiteSafety-YOLO\notebooks\..\data\input\test_image.png: 384x640 2 persons, 84.6ms
# Speed: 4.3ms preprocess, 84.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)

# %% [markdown]
# # Model Exploration
